# %%
import os,sys
import scanpy as sc
import numpy as np
import pandas as pd
import seaborn as sns
from plotnine import *
from functools import reduce
from pathlib import Path
import re
import glob
import matplotlib.pyplot as plt

# %%
def classify_sgrna(df):
    df['sgRNA_type'] = 'single sgRNA'
    # overwrite where gRNA is missing
    df.loc[df['guide_id'].isna(), 'sgRNA_type'] = 'no sgRNA'
    df.loc[df['guide_id'].str.startswith('NTC', na=False), 'sgRNA_type'] = 'single NTC sgRNA'
    df.loc[df['guide_id'].str.startswith('multi', na=False), 'sgRNA_type'] = 'multi sgRNA'
    # Order the rows
    type_order = ['single sgRNA','single NTC sgRNA','multi sgRNA','no sgRNA']
    df['sgRNA_type'] = pd.Categorical(df['sgRNA_type'],categories=type_order,ordered=True)
    # df = df.loc[:, ['n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts',
                    # 'gRNA', 'guide_id', 'UMI_counts', 'target_gene','sgRNA_type']]
    return df

# %%
def plot_lane_sgRNA(df):
    p = (
        ggplot(df, aes(x = 'condition', fill = 'sgRNA_type'))
        + geom_bar(position="stack")
        + scale_fill_brewer(type='sequential', palette= 5, direction= -1)
        + labs(x = 'Condition',
              y = 'Cell counts')
        + theme_bw()
        + theme(figure_size=(5, 3),
                legend_title=element_blank(),
                axis_text_x=element_text(rotation=90, 
                                         hjust=1))
        + theme(
            plot_title=element_text(size=16, face="bold", ha='center'),
            axis_title_x=element_text(size=18),
            axis_title_y=element_text(size=18),
            axis_text_x=element_text(size=10),
            axis_text_y=element_text(size=10)
            )
        )
    return p

# %%
path = '/Users/chandrima.modak/Gladstone Dropbox/Chandrima Modak/macs_perturbseq_analysis'
files = [file for file in os.listdir(path) if file.startswith('Mac_')]
files = sorted(files)
files
# Out:
# ['Mac_L01_Mac_Ctrl',
#  'Mac_L01_Mac_LPS',
#  'Mac_L02_Mac_Ctrl',
#  'Mac_L02_Mac_LPS',
#  'Mac_L03_Mac_Ctrl',
#  'Mac_L03_Mac_LPS',
#  'Mac_L04_Mac_Ctrl',
#  'Mac_L04_Mac_LPS']

# %%
df1 = pd.DataFrame()
for i in range(0,len(files)):
    df = pd.DataFrame()
    path = f'/Users/chandrima.modak/Gladstone Dropbox/Chandrima Modak/macs_perturbseq_analysis/{files[i]}/'
    guide_pattern = glob.glob(os.path.join(path, "*_gex_guide.h5ad"))[0]
    # print(guide_pattern)
    adata = sc.read_h5ad(guide_pattern)
    df = adata.obs
    df_guide = classify_sgrna(df)
    df_guide['experiment'] = files[i]
    #     df = pd.concat([df, df_guide])
    df1 = pd.concat([df1, df_guide])

# %%
df1['condition'] = df1['experiment'].apply(lambda x: ' '.join(x.split('_')[2:4]))
df1.head()
# Out:
#                                              n_genes_by_counts  \
# AAACAAGCAAACAATCAACGGGAA-1_Mac_Ctrl_Mac_L01               3810
# AAACAAGCAAACAATCAAGTAGAG-1_Mac_Ctrl_Mac_L01               3648
# AAACAAGCAAACCGTAAACGGGAA-1_Mac_Ctrl_Mac_L01               3660
# AAACAAGCAAAGAACAACTTTAGG-1_Mac_Ctrl_Mac_L01               3879
# AAACAAGCAAAGCTCAAACGGGAA-1_Mac_Ctrl_Mac_L01               3406
#
#                                              log1p_n_genes_by_counts  \
# AAACAAGCAAACAATCAACGGGAA-1_Mac_Ctrl_Mac_L01                 8.245647
# AAACAAGCAAACAATCAAGTAGAG-1_Mac_Ctrl_Mac_L01                 8.202208
# AAACAAGCAAACCGTAAACGGGAA-1_Mac_Ctrl_Mac_L01                 8.205492
# AAACAAGCAAAGAACAACTTTAGG-1_Mac_Ctrl_Mac_L01                 8.263590
# AAACAAGCAAAGCTCAAACGGGAA-1_Mac_Ctrl_Mac_L01                 8.133587
#
#                                              total_counts        gRNA  \
# AAACAAGCAAACAATCAACGGGAA-1_Mac_Ctrl_Mac_L01       10902.0  HIST1H3G-1
# AAACAAGCAAACAATCAAGTAGAG-1_Mac_Ctrl_Mac_L01       11141.0      ITPA-4
# AAACAAGCAAACCGTAAACGGGAA-1_Mac_Ctrl_Mac_L01        8691.0     NTC-453
# AAACAAGCAAAGAACAACTTTAGG-1_Mac_Ctrl_Mac_L01       12200.0   TRAPPC9-2
# AAACAAGCAAAGCTCAAACGGGAA-1_Mac_Ctrl_Mac_L01        8737.0     GSDMC-1
#
#                                                 guide_id  UMI_counts  \
# AAACAAGCAAACAATCAACGGGAA-1_Mac_Ctrl_Mac_L01   HIST1H3G-1       149.0
# AAACAAGCAAACAATCAAGTAGAG-1_Mac_Ctrl_Mac_L01  multi_sgRNA       184.0
# AAACAAGCAAACCGTAAACGGGAA-1_Mac_Ctrl_Mac_L01  multi_sgRNA        37.0
# AAACAAGCAAAGAACAACTTTAGG-1_Mac_Ctrl_Mac_L01  multi_sgRNA        30.0
# AAACAAGCAAAGCTCAAACGGGAA-1_Mac_Ctrl_Mac_L01  multi_sgRNA        95.0
#
#                                              target_gene    sgRNA_type  \
# AAACAAGCAAACAATCAACGGGAA-1_Mac_Ctrl_Mac_L01     HIST1H3G  single sgRNA
# AAACAAGCAAACAATCAAGTAGAG-1_Mac_Ctrl_Mac_L01  multi_sgRNA   multi sgRNA
# AAACAAGCAAACCGTAAACGGGAA-1_Mac_Ctrl_Mac_L01  multi_sgRNA   multi sgRNA
# AAACAAGCAAAGAACAACTTTAGG-1_Mac_Ctrl_Mac_L01  multi_sgRNA   multi sgRNA
# AAACAAGCAAAGCTCAAACGGGAA-1_Mac_Ctrl_Mac_L01  multi_sgRNA   multi sgRNA
#
#                                                    experiment condition
# AAACAAGCAAACAATCAACGGGAA-1_Mac_Ctrl_Mac_L01  Mac_L01_Mac_Ctrl  Mac Ctrl
# AAACAAGCAAACAATCAAGTAGAG-1_Mac_Ctrl_Mac_L01  Mac_L01_Mac_Ctrl  Mac Ctrl
# AAACAAGCAAACCGTAAACGGGAA-1_Mac_Ctrl_Mac_L01  Mac_L01_Mac_Ctrl  Mac Ctrl
# AAACAAGCAAAGAACAACTTTAGG-1_Mac_Ctrl_Mac_L01  Mac_L01_Mac_Ctrl  Mac Ctrl
# AAACAAGCAAAGCTCAAACGGGAA-1_Mac_Ctrl_Mac_L01  Mac_L01_Mac_Ctrl  Mac Ctrl

# %%
qc_path = '/Users/chandrima.modak/Gladstone Dropbox/Chandrima Modak/macs_perturbseq_analysis/qc_stats'
os.makedirs(qc_path, exist_ok= True)
df1.to_csv(os.path.join(qc_path, 'metadata_all_lane_qc.csv'))

# %%
plt_path = '/Users/chandrima.modak/Gladstone Dropbox/Chandrima Modak/macs_perturbseq_analysis/plots'
# os.makedirs(plt_path, exist_ok= True)
# plt_c = plot_lane_sgRNA(df1)
# plt_c = plt_c + theme(
#     panel_grid_major = element_blank(),
#     panel_grid_minor = element_blank(),
#     axis_text_x=element_text(size=14),
#     axis_text_y=element_text(size=14),
#     legend_text=element_text(size=12),
#     figure_size = (5, 5)
# )
# plt_c.save(os.path.join(plt_path, 'sgRNA_type_distribution.pdf'), dpi= 300)
# plt_c.show()

# %% [markdown]
# #

# %% [markdown]
# # Expression Pattern of all the cells

# %%
df1.groupby(['condition', 'sgRNA_type']).size()
# Out:
# /var/folders/lh/8shkr2ln1lz628fhh9nfhqh00000gp/T/ipykernel_84119/1295668211.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# condition  sgRNA_type
# Mac Ctrl   single sgRNA         89111
#            single NTC sgRNA     23309
#            multi sgRNA         458416
#            no sgRNA              3784
# Mac LPS    single sgRNA         99161
#            single NTC sgRNA     25783
#            multi sgRNA         549525
#            no sgRNA              3998
# dtype: int64

# %%
adatas = []
for i in range(0,len(files)):
    df = pd.DataFrame()
    path = f'/Users/chandrima.modak/Gladstone Dropbox/Chandrima Modak/macs_perturbseq_analysis/{files[i]}/'
    guide_pattern = glob.glob(os.path.join(path, "*_gex_guide.h5ad"))[0]
    # print(guide_pattern)
    adata = sc.read_h5ad(guide_pattern)
    adata = adata[adata.obs.guide_id.str.startswith('NTC',  na=False)].copy()
    # sc.pp.normalize_total(adata)
    # sc.pp.log1p(adata)
    adatas.append(adata)

# %%
import anndata
adata_merge = anndata.concat(adatas, join='outer')

# %%
# Run the split/join on the merged object itself
adata_merge.obs['condition'] = adata_merge.obs['lane_id'].apply(lambda x : ' '.join(x.split('_')))
adata_merge.obs
# Out:
#                                             library_id   lane_id  \
# AAACAAGCATCAGGTAATCCCAAC-1_Mac_Ctrl_Mac_L01    Mac_L01  Mac_Ctrl
# AAACCAATCAACCGGAACTTTAGG-1_Mac_Ctrl_Mac_L01    Mac_L01  Mac_Ctrl
# AAACCAATCACCTTTCAGTAGGCT-1_Mac_Ctrl_Mac_L01    Mac_L01  Mac_Ctrl
# AAACCAATCTATCGGCACAGACCT-1_Mac_Ctrl_Mac_L01    Mac_L01  Mac_Ctrl
# AAACCAATCTCAAACTAAGTAGAG-1_Mac_Ctrl_Mac_L01    Mac_L01  Mac_Ctrl
# ...                                                ...       ...
# TTTGGCGGTAGGAGGAATCATGTG-1_Mac_LPS_Mac_L04     Mac_L04   Mac_LPS
# TTTGGCGGTATTCGTAACTACTCA-1_Mac_LPS_Mac_L04     Mac_L04   Mac_LPS
# TTTGGCGGTGATCCTGATTCGGTT-1_Mac_LPS_Mac_L04     Mac_L04   Mac_LPS
# TTTGGCGGTTGGATGAAGTGAGTG-1_Mac_LPS_Mac_L04     Mac_L04   Mac_LPS
# TTTGTGAGTGGTTCGCATTCGGTT-1_Mac_LPS_Mac_L04     Mac_L04   Mac_LPS
#
#                                              n_genes_by_counts  \
# AAACAAGCATCAGGTAATCCCAAC-1_Mac_Ctrl_Mac_L01               3260
# AAACCAATCAACCGGAACTTTAGG-1_Mac_Ctrl_Mac_L01               3799
# AAACCAATCACCTTTCAGTAGGCT-1_Mac_Ctrl_Mac_L01               3804
# AAACCAATCTATCGGCACAGACCT-1_Mac_Ctrl_Mac_L01               3927
# AAACCAATCTCAAACTAAGTAGAG-1_Mac_Ctrl_Mac_L01               4647
# AAACCAATCTATCGGCACAGACCT-1_Mac_Ctrl_Mac_L01  NTC-400         NTC       107.0
# AAACCAATCTCAAACTAAGTAGAG-1_Mac_Ctrl_Mac_L01  NTC-330         NTC        33.0
# ...                                              ...         ...         ...
# TTTGGCGGTAGGAGGAATCATGTG-1_Mac_LPS_Mac_L04   NTC-335         NTC        34.0
# TTTGGCGGTATTCGTAACTACTCA-1_Mac_LPS_Mac_L04   NTC-158         NTC        37.0
# TTTGGCGGTGATCCTGATTCGGTT-1_Mac_LPS_Mac_L04   NTC-385         NTC       233.0
# TTTGGCGGTTGGATGAAGTGAGTG-1_Mac_LPS_Mac_L04   NTC-175         NTC       151.0
# TTTGTGAGTGGTTCGCATTCGGTT-1_Mac_LPS_Mac_L04   NTC-494         NTC        32.0
#
#                                             condition
# AAACAAGCATCAGGTAATCCCAAC-1_Mac_Ctrl_Mac_L01  Mac Ctrl
# AAACCAATCAACCGGAACTTTAGG-1_Mac_Ctrl_Mac_L01  Mac Ctrl
# AAACCAATCACCTTTCAGTAGGCT-1_Mac_Ctrl_Mac_L01  Mac Ctrl
# AAACCAATCTATCGGCACAGACCT-1_Mac_Ctrl_Mac_L01  Mac Ctrl
# AAACCAATCTCAAACTAAGTAGAG-1_Mac_Ctrl_Mac_L01  Mac Ctrl
# ...                                               ...
# TTTGGCGGTAGGAGGAATCATGTG-1_Mac_LPS_Mac_L04    Mac LPS
# TTTGGCGGTATTCGTAACTACTCA-1_Mac_LPS_Mac_L04    Mac LPS
# TTTGGCGGTGATCCTGATTCGGTT-1_Mac_LPS_Mac_L04    Mac LPS
# TTTGGCGGTTGGATGAAGTGAGTG-1_Mac_LPS_Mac_L04    Mac LPS
# TTTGTGAGTGGTTCGCATTCGGTT-1_Mac_LPS_Mac_L04    Mac LPS
#
# [49092 rows x 19 columns]

# %%
vars_list = ["CD14", "CD68", "CD40",
            "IL1B", "CXCL8", "CCL2", "IL6", "CD80", "CD86", "SPP1", "MRC1", "MARCO", "CD163", "MSR1"]

# %%
axes = sc.pl.dotplot(adata_merge, 
                     groupby="condition", 
                     var_names=vars_list, 
                     figsize=(12, 4),
                     show=False)

axes['mainplot_ax'].tick_params(axis='x', labelsize=14)
axes['mainplot_ax'].tick_params(axis='y', labelsize=14)
axes['color_legend_ax'].tick_params(labelsize=12)
axes['color_legend_ax'].title.set_size(12)
axes['size_legend_ax'].tick_params(labelsize=12)
axes['size_legend_ax'].title.set_size(12)

plt.subplots_adjust(bottom=0.25)  # make room for rotated labels
plt.savefig(os.path.join(plt_path, 'genes_expression_on_ntc.pdf'), 
            dpi=300, bbox_inches='tight')
plt.show()

# %%
adata_merge.var_names[adata_merge.var_names.str.startswith("CD6")]
# Out:
# Index(['CD6', 'CD69', 'CD63', 'CD68'], dtype='object')

# %%
df1['condition'] = df1['lane_id'].apply(lambda x : ' '.join(x.split('_')))

# %%
df_single =  df1[df1['sgRNA_type'].str.startswith("single")]
df_single
# Out:
# /var/folders/lh/8shkr2ln1lz628fhh9nfhqh00000gp/T/ipykernel_8166/3029703766.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                             library_id   lane_id  \
# AAACAAGCAAACAATCAACGGGAA-1_Mac_Ctrl_Mac_L
# TTTGTGAGTGTGAGACACTACTCA-1_Mac_LPS_Mac_L04    Mac_L04_Mac_LPS   Mac LPS
# TTTGTGAGTTCACTCCATCATGTG-1_Mac_LPS_Mac_L04    Mac_L04_Mac_LPS   Mac LPS
# TTTGTGAGTTGGGTTTATCATGTG-1_Mac_LPS_Mac_L04    Mac_L04_Mac_LPS   Mac LPS
#
# [237364 rows x 21 columns]

# %%
df_single =  df1[df1['sgRNA_type'].str.startswith("single")]
df_target = (
    df_single
    .groupby(['target_gene', 'condition'])
    .size()
    .reset_index(name='n_cells')
)

df_target.groupby('condition')['n_cells'].mean()
# Out:
# /var/folders/lh/8shkr2ln1lz628fhh9nfhqh00000gp/T/ipykernel_8166/636661929.py:4: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# condition
# Mac Ctrl    196.882662
# Mac LPS     218.816112
# Name: n_cells, dtype: float64

# %%
# Step 1: Count cells for every individual gRNA
grna_coverage = df_sgumi.groupby(['target_gene', 'gRNA', 'condition']).size().reset_index(name='cell_count')

# Step 2: Average those counts across the guides for each gene
mean_cells_per_guide = grna_coverage.groupby(['target_gene', 'condition'])['cell_count'].mean().reset_index(name='mean_cells_per_guide')

# %%
df2 = pd.DataFrame()
for i in range(0,len(files)):
    df = pd.DataFrame()
    path = f'/Users/chandrima.modak/Gladstone Dropbox/Chandrima Modak/macs_perturbseq_analysis/{files[i]}/'
    guide_pattern = glob.glob(os.path.join(path, "*_crispr_preprocessed.h5ad"))[0]
    # print(guide_pattern)
    adata = sc.read_h5ad(guide_pattern)
    df = adata.obs
    df = df.rename(columns={'lane_id': 'condition', 'total_counts': 'umi_counts_raw'})
    df['condition'] = df['condition'].apply(lambda x: ' '.join(x.split('_')))
    # df_guide = classify_sgrna(df)
    # df_guide['experiment'] = files[i]
    #     df = pd.concat([df, df_guide])
    df2 = pd.concat([df2, df])

df_sgumi = pd.DataFrame()
for i in range(0,len(files)):
    df = pd.DataFrame()
    path = f'/Users/chandrima.modak/Gladstone Dropbox/Chandrima Modak/macs_perturbseq_analysis/{files[i]}/'
    guide_pattern = glob.glob(os.path.join(path, "guide_assigned.csv"))[0]
    # print(guide_pattern)
    df = pd.read_csv(guide_pattern)
    # df_agg = df.groupby("cell").agg(
        # sum_sgrna_umi = ('UMI_counts', 'sum')
    # )
    df['condition'] = ' '.join(files[i].split('_')[2:4])
    #     df = pd.concat([df, df_guide])
    df_sgumi = pd.concat([df_sgumi, df])

df_sgumi['target_gene'] =  df_sgumi.gRNA.str.split('-').str[0]
sum_umi_per_cell = df_sgumi.groupby(['cell', 'condition'])['UMI_counts'].sum().reset_index(name='sum_sgrna_umi_per_cell')
df_merge = pd.merge(df2['umi_counts_raw'].to_frame(), mean_umi_per_cell, how= 'outer', right_index=True, left_index=True)

# %%
df_merge.columns
# Out:
# Index(['umi_counts_raw', 'condition', 'sum_sgrna_umi_per_cell'], dtype='object')

# %%
# Average the UMI counts across all guides detected within each unique cell

# If you want a single summary number per condition:
condition_umi_summary = df_merge.groupby('condition').agg(
    mean_raw_umi = ('umi_counts_raw', 'mean'),
    mean_assign_umi = ('sum_sgrna_umi_per_cell', 'mean')
)
condition_umi_summary
# mean_umi_per_cell['guide_id'] = np.where(assignment_size[mean_umi_per_cell['cell']].values > 1, 'multi_sgRNA', 'single_sgRNA')
# Out:
#            mean_raw_umi  mean_assign_umi
# condition
# Mac Ctrl     207.632690       199.587645
# Mac LPS      269.652588       257.714891

# %%
guide_cells_summary = mean_cells_per_guide.groupby('condition')['mean_cells_per_guide'].mean()

# %%
# Summary at the gRNA level including the target_gene information
# df_summary = df_sgumi.groupby(['target_gene', 'gRNA', 'condition']).agg(
#     n_cells=('cell', 'count'),
#     mean_sgumi=('UMI_counts', 'mean')
# ).reset_index()
# df_summary.groupby(['target_gene', 'condition']).agg(
#     mean_n_cells = ('n_cells', 'mean'),
#     mean_umi_cells = ('mean_sgumi', 'mean')
# )
# df_summary

# %%
df_raw_plot = df1.groupby(['condition']).agg(
    # n_cells=('gRNA', 'size'),
    mean_mito = ('pct_counts_mt', 'mean'),
    mean_UMI = ('total_counts', 'mean'),
    mean_genes = ('n_genes', 'mean')
)
df_raw_plot
# Out:
#            mean_mito      mean_UMI   mean_genes
# condition
# Mac Ctrl    0.099674  14804.008789  4350.456449
# Mac LPS     0.118703  16563.259766  4305.693808

# %%
df_combined = pd.concat([df_raw_plot, condition_umi_summary, guide_cells_summary], axis=1)
df_combined.reset_index(inplace=True)

# %%
df_combined
# Out:
#   condition  mean_mito      mean_UMI   mean_genes  mean_raw_umi  \
# 0  Mac Ctrl   0.099674  14804.008789  4350.456449    207.632690
# 1   Mac LPS   0.118703  16563.259766  4305.693808    269.652588
#
#    mean_assign_umi  mean_cells_per_guide
# 0       199.587645            650.633662
# 1       257.714891            801.567142

# %%
fig, ax = plt.subplots(2,3, figsize = (18,12))
ax = ax.flatten()
titles = ["Mean Cells per Guide", "Mean Guide raw UMI per Cell", "Mean Assigned Guide UMI per Cell", 
          "Mean mRNA UMIs per Cell", "Mean Genes per Cell", "Mean %Mitochondrial UMIs per Cell"]
sns.barplot(
    df_combined,
    x = 'condition',
    y = 'mean_cells_per_guide',
    hue="condition",
    ax = ax[0]
)
sns.barplot(
    df_combined,
    x = 'condition',
    y = 'mean_raw_umi',
    hue="condition",
    ax = ax[1]
)
sns.barplot(
    df_combined,
    x = 'condition',
    y = 'mean_assign_umi',
    hue="condition",
    ax = ax[2]
)
sns.barplot(
    df_combined,
    x = 'condition',
    y = 'mean_UMI',
    hue="condition",
    ax = ax[3]
)
sns.barplot(
    df_combined,
    x = 'condition',
    y = 'mean_genes',
    hue="condition",
    ax = ax[4]
)
sns.barplot(
    df_combined,
    x = 'condition',
    y = 'mean_mito',
    hue="condition",
    ax = ax[5]
)
ax[5].set_ylim([0, 1])
for i, title in enumerate(titles):
    ax[i].set_ylabel(title, fontsize=20)
    ax[i].tick_params(axis='both', which='major', labelsize=18)
    ax[i].set_xlabel("Condition", fontsize=20)
plt.subplots_adjust(left=0.1, right=0.9, 
                    top=0.9, bottom=0.1, 
                    wspace=0.4, hspace=0.4)
plt.tight_layout()
plt.savefig(os.path.join(plt_path, "QC_data_for_all_condition.pdf"), dpi = 300)
